# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm

# Load the time series data
data = pd.read_csv('C:/Users/hieu7/Downloads/AMZN.csv')

# %%
data
# Out:
#             Date        Open        High        Low       Close   Adj Close  \
# 0     1997-05-15    0.121875    0.125000   0.096354    0.097917    0.097917
# 1     1997-05-16    0.098438    0.098958   0.085417    0.086458    0.086458
# 2     1997-05-19    0.088021    0.088542   0.081250    0.085417    0.085417
# 3     1997-05-20    0.086458    0.087500   0.081771    0.081771    0.081771
# 4     1997-05-21    0.081771    0.082292   0.068750    0.071354    0.071354
# ...          ...         ...         ...        ...         ...         ...
# 6504  2023-03-21   98.139999  100.849998  98.000000  100.610001  100.610001
# 6505  2023-03-22  100.449997  102.099998  98.610001   98.699997   98.699997
# 6506  2023-03-23  100.430000  101.059998  97.620003   98.709999   98.709999
# 6507  2023-03-24   98.070000   98.300003  96.400002   98.129997   98.129997
# 6508  2023-03-27   99.070000   99.339996  97.080002   98.040001   98.040001
#
#           Volume
# 0     1443120000
# 1      294000000
# ...

# %%
data_range=data.loc[(data["Date"]>=start)& (data["Date"]<=end)] #select data from a range
data_range["Date"]=pd.to_datetime(data_range["Date"], format='%Y-%m-%d')

data_range.set_index(["Date"],inplace=True)
x=arange(len(data_range)) 
y=data_range[prop]    
figure(figsize=(27,8)) # setting fig size
plot(y)
z = np.polyfit(x, y, fit)
p = np.poly1d(z)
plt.title(prop+" price")
xlabel("Times")
ylabel("Price(USD)")
plot(x, p(x),'r-.')
show()
# Out:
# C:\Users\hieu7\AppData\Local\Temp\ipykernel_12072\313459268.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_range["Date"]=pd.to_datetime(data_range["Date"], format='%Y-%m-%d')

# %%
def plots(start,end,prop):
    data_range=data.loc[(data["Date"]>=start)& (data["Date"]<=end)] #select data from a range 
    x=arange(len(data_range)) 
    y=data_range[prop]
    figure(figsize=(27,8)) # setting fig size
    plot(x,y)
    plt.title(prop+" price")
    xlabel("Times")
    ylabel("Price(USD)")
    show()

# %%
from pylab import *
import numpy as np
def trends(start,end,prop,fit):
    data_range=data.loc[(data["Date"]>=start)& (data["Date"]<=end)] #select data from a range
    x=arange(len(data_range)) 
    y=data_range[prop] 
    figure(figsize=(27,8)) # setting fig size
    scatter(x,y)
    z = np.polyfit(x, y, fit)
    p = np.poly1d(z)
    plt.title(prop+" price")
    xlabel("Times")
    ylabel("Price(USD)")
    plot(x, p(x),'r-.')
    show()

# %%
data["Date"]=pd.to_datetime(data['Date'], format='%Y-%m-%d')
data.set_index(["Date"],inplace=True)
plt.plot(data["Open"])

# %%
data_range=data.loc[(data["Date"]>=start)& (data["Date"]<=end)] #select data from a range

# %%
data_range=pd.DataFrame(data_range)

# %%
data_range
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 6239  2022-03-01  152.732498  154.098999  149.977005  151.141998  151.141998
# 6240  2022-03-02  150.848999  152.999496  148.750000  152.052505  152.052505
# 6241  2022-03-03  153.531494  153.929001  146.856003  147.898499  147.898499
# 6242  2022-03-04  147.158997  147.850006  143.807007  145.641006  145.641006
# 6243  2022-03-07  145.443497  146.094498  137.416504  137.453003  137.453003
# ...          ...         ...         ...         ...         ...         ...
# 6504  2023-03-21   98.139999  100.849998   98.000000  100.610001  100.610001
# 6505  2023-03-22  100.449997  102.099998   98.610001   98.699997   98.699997
# 6506  2023-03-23  100.430000  101.059998   97.620003   98.709999   98.709999
# 6507  2023-03-24   98.070000   98.300003   96.400002   98.129997   98.129997
# 6508  2023-03-27   99.070000   99.339996   97.080002   98.040001   98.040001
#
#         Volume
# 6239  44874000
# ...

# %%
data_range["Date"]=pd.to_datetime(data_range["Date"], format='%Y-%m-%d')
data_range.set_index(["Date"],inplace=True)

# %%
figure(figsize=(27,8))
plt.plot(data_range["Open"])

# %%
x=arange(len(data_range["Open"]))
y=data_range["Open"]
z = np.polyfit(x, y, fit)
p = np.poly1d(z)
plt.title(prop+" price")
xlabel("Times")
ylabel("Price(USD)")
plt.plot(x, p(x),'r-.')
plt.show()
